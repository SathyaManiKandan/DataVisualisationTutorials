# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
apples = [23,123,3412,31231,24,123];

# %%
plt.plot(apples);

# %%
years = [2010,2011,2012,2013,2014,2015]

# %%
plt.plot(years, apples);
plt.xlabel('Year')
plt.ylabel('Apples')
# Out:
# Text(0, 0.5, 'Apples')

# %%
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]

# %%
plt.plot(years, apples)
plt.plot(years, oranges);
plt.xlabel('Year')
plt.ylabel('Fruits')
# Out:
# Text(0, 0.5, 'Fruits')

# %%
plt.plot(years, apples)
plt.plot(years, oranges)

plt.xlabel('Year')
plt.ylabel('Fruits')

plt.legend(['apples', 'oranges'])

# %%
plt.plot(years, apples, marker = 'o')
plt.plot(years, oranges, marker = 'x')

plt.xlabel('Years')
plt.ylabel('Fruits')

plt.legend(['apples', 'oranges'])
plt.title('Crops Yiels in Kanto')
# Out:
# Text(0.5, 1.0, 'Crops Yiels in Kanto')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7136/1807035400.py in <module>
#       1 import pandas as pd
# ----> 2 apples.plot(apples)
#
# AttributeError: 'list' object has no attribute 'plot'

# %%
plt.plot(apples)

# %%
plt.plot(years, apples, marker = 'o', c = 'r' , ls = '--' , lw = '2', mec = 'r', mfc = 'b' , ms =  '29', mew = '2', alpha = .6 )
plt.plot(years, oranges, marker = 'x', c = 'b')

plt.xlabel('Years')
plt.ylabel('Fruits')

plt.title("Production in Kunta")
plt.legend(['apples', 'oranges'])

# %%
plt.figure(figsize = (12, 5))
sns.set_style('darkgrid')
plt.plot(years, apples, 's-b')
plt.plot(years, oranges, 'o--r')

plt.xlabel('Year')
plt.ylabel('Yield')

plt.title("Crops yield in Kanto")

plt.legend(["Apples", 'Oranges'])

# %%
plt.plot(years, apples, 's-b')

# %%
flowers_df = sns.load_dataset('iris')

# %%
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.plot(flowers_df['sepal_length'])

# %%
plt.hist(flowers_df['sepal_width']);
plt.title("Distribution Of Sepal Width")
# Out:
# Text(0.5, 1.0, 'Distribution Of Sepal Width')

# %%
plt.hist(flowers_df['sepal_width'], bins = [ 1, 2, 3, 4, 5, 10] , color = 'g')
# Out:
# (array([ 0., 57., 89.,  4.,  0.]),
#  array([ 1,  2,  3,  4,  5, 10]),
#  <BarContainer object of 5 artists>)

# %%
setosa_df = flowers_df[flowers_df.species == 'setosa']
versicolor_df = flowers_df[flowers_df.species == 'versicolor']
virginica_df = flowers_df[flowers_df.species == 'virginica']

# %%
setosa_df
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
years = range(2000, 2006)
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

# %%
plt.bar(years, oranges)
plt.bar(years, apples , bottom = oranges)
plt.legend(['oranges', 'apples'])

# %%
plt.bar(years, oranges)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(years, apples)
# Out:
# <BarContainer object of 6 artists>

# %%
tips_df = sns.load_dataset("tips");

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import urllib.request

# %%
urllib.request.urlretrieve('https://i.imgur.com/SkPbq.jpg', 'chart.jpg')
# Out:
# ('chart.jpg', <http.client.HTTPMessage at 0x18278c31cd0>)

# %%
import PIL.Image

# %%
 img = PIL.Image.open('chart.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x481 at 0x18278D02430>
